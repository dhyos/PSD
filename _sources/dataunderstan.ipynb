# %% [markdown]
# # Understanding data
#
# Dalam kerangka kerja CRISP-DM (Cross Industry Standard Process for Data Mining), tahap Data Understanding merupakan langkah kedua setelah Business Understanding. Tujuannya adalah untuk memahami data yang dimiliki secara menyeluruh sebelum masuk ke tahap pemodelan

# %% [markdown]
# ## 📊 Macam-macam Tipe Data
#
# Data dalam ilmu data dapat diklasifikasikan dari berbagai sudut pandang. Berikut adalah penjelasan tipe data ditinjau dari **sifat**, **sumber**, **representasi**, dan **struktur**:
#
# ---
#
# ### 1. Ditinjau dari **Sifat Data**
#
# * **Data Kualitatif (Qualitative Data)**
#
#   * Data berbentuk kategori atau deskripsi, tidak berupa angka.
#   * Contoh: jenis kelamin (laki-laki/perempuan), warna mobil, merek motor.
# * **Data Kuantitatif (Quantitative Data)**
#
#   * Data berbentuk angka, bisa dihitung dan diukur.
#   * Dibagi menjadi:
#
#     * **Diskrit (Discrete)** → berupa hitungan, tidak bisa pecahan. Contoh: jumlah unit terjual.
#     * **Kontinu (Continuous)** → berupa ukuran, bisa dalam pecahan. Contoh: harga kendaraan, tinggi badan.
#
# ---
#
# ### 2. Ditinjau dari **Sumber Data**
#
# * **Data Primer**
#
#   * Data diperoleh langsung dari sumber pertama melalui survei, wawancara, observasi, atau eksperimen.
#   * Contoh: kuesioner pelanggan PT. Hasjrat Abadi.
# * **Data Sekunder**
#
#   * Data diperoleh dari pihak lain atau sumber yang sudah tersedia.
#   * Contoh: laporan keuangan perusahaan, data BPS, dataset publik dari Kaggle.
#
# ---
#
# ### 3. Ditinjau dari **Representasi Data**
#
# * **Data Numerik**
#
#   * Direpresentasikan dalam bentuk angka.
#   * Contoh: harga, kuantitas penjualan, umur.
# * **Data Kategorikal**
#
#   * Direpresentasikan dalam bentuk kategori/label.
#   * Contoh: tipe kendaraan (MPV, SUV, Hatchback).
# * **Data Ordinal**
#
#   * Direpresentasikan sebagai kategori tetapi ada tingkatan.
#   * Contoh: kepuasan pelanggan (sangat puas, puas, kurang puas).
# * **Data Biner**
#
#   * Hanya memiliki dua nilai.
#   * Contoh: Ya/Tidak, Aktif/Nonaktif.
# * **Data Teks & Multimedia**
#
#   * Representasi dalam bentuk unstructured data.
#   * Contoh: ulasan pelanggan (text), foto kendaraan (image), rekaman iklan (video).
#
# ---
#
# ### 4. Ditinjau dari **Struktur Data**
#
# * **Data Terstruktur (Structured Data)**
#
#   * Tersimpan dalam format tabel dengan baris dan kolom yang jelas.
#   * Contoh: database SQL berisi data transaksi.
# * **Data Semi Terstruktur (Semi-Structured Data)**
#
#   * Tidak seketat tabel, tetapi masih punya label/tag.
#   * Contoh: file XML, JSON, log server.
# * **Data Tidak Terstruktur (Unstructured Data)**
#
#   * Tidak punya format tertentu, biasanya data teks bebas atau media.
#   * Contoh: komentar media sosial, gambar produk, video iklan.

# %% [markdown]
# ## Pengumpulan Data
#
# Dalam tahap ini kita harus mendapatkna data dari perusahaan PT. Hasjrat Abadi Lapulu bisa menggunakan data primer yaitu data yang kita peroleh langsung di lapangan atau data sekunder yang bisa kita dapatkan lewat media seperti https://www.kaggle.com/ dll. disini saya menggunakan data yang tersedia di kagle https://www.kaggle.com/datasets/raflyahmadzainur/dataset-pt-hasjrat-abadi-lapulu kita bisa mendowload data tersebut atau menarik datanya langsung dari kagle. Saya akan mencoba menarik datanya langsung dari kagle. dnegan menyalin code yang tersedia pada dataset tersebut

# %% [markdown]
# ### Install lIbrary yang dibutuhkan

# %%
# !pip install kagglehub[pandas-datasets]
# !pip install tabulate
# !pip install ydata_profiling
# Out:
# Requirement already satisfied: kagglehub[pandas-datasets] in /usr/local/lib/python3.12/dist-packages (0.3.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub[pandas-datasets]) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub[pandas-datasets]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub[pandas-datasets]) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub[pandas-datasets]) (4.67.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from kagglehub[pandas-datasets]) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->kagglehub[pandas-datasets]) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->kagglehub[pandas-datasets]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->kagglehub[pandas-datasets]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->kagglehub[pandas-datasets]) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub[pandas-datasets]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub[pandas-datasets]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub[pandas-datasets]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub[pandas-datasets]) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->kagglehub[pandas-datasets]) (1.17.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Collecting ydata_profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting scipy<1.16,>=1.4.1 (from ydata_profiling)
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (2.0.2)
# Collecting htmlmin==0.1.12 (from ydata_profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata_profiling)
#   Downloading phik-0.12.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata_profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (4.4.4)
# Collecting imagehash==4.3.1 (from ydata_profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (1.9.4)
# Collecting dacite>=1.8 (from ydata_profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /usr/local/lib/python3.12/dist-packages (from ydata_profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.12/dist-packages (from imagehash==4.3.1->ydata_profiling) (1.9.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from imagehash==4.3.1->ydata_profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<=0.61,>=0.56.0->ydata_profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata_profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata_profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->ydata_profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->ydata_profiling) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->ydata_profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->ydata_profiling) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.5)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.17.0)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 10.1 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 23.4 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 45.0 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 49.5 MB/s eta 0:00:00
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.0 MB/s eta 0:00:00
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.4 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=87d2b83bfaf8a58ad0f564bb677fc39d926214e861f78f75199a6207324787fa
#   Stored in directory: /root/.cache/pip/wheels/5f/d4/d7/4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# Installing collected packages: puremagic, htmlmin, scipy, multimethod, dacite, imagehash, visions, phik, ydata_profiling
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# Successfully installed dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 phik-0.12.5 puremagic-1.30 scipy-1.15.3 visions-0.8.1 ydata_profiling-4.16.1

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Nama file sesuai dataset Kaggle
file_path = "Dataset PT Hasjrat Abadi.csv"

# Load dataset ke pandas dataframe (dengan encoding fallback)
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "raflyahmadzainur/dataset-pt-hasjrat-abadi-lapulu",
    file_path,
    pandas_kwargs={
        "sep":';',
        "encoding": "latin1"  # atau "ISO-8859-1" jika tetap error
    }
)
# Out:
# /tmp/ipython-input-460715300.py:8: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(

# %%
import pandas as pd
from tabulate import tabulate
if "id" not in df.columns:
  df.insert(0, "id", range(1, len(df) + 1))
head_data = df.head(5)
tail_data = df.tail(5)

# Gabungkan dengan pemisah "......."
separator = pd.DataFrame([["...." for _ in df.columns]], columns=df.columns)

# Gabungan
combined = pd.concat([head_data, separator, tail_data], ignore_index=True)

# Tampilkan dalam bentuk tabel
print(tabulate(combined, headers="keys", tablefmt="grid",showindex=False))
# Out:
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | id    | No Faktur   | Model            | Kuantitas   | Tanggal Pemesanan   | Harga      | ID Pelanggan   | Tempat Tinggal      |
# +=======+=============+==================+=============+=====================+============+================+=====================+
# | 1     | 489434      | MIO M3 CW        | 1.0         | 06/06/2024          | 20,500,000 | 17850.0        | KOTA KENDARI        |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 2     | 489434      | JUPITER Z CW FI  | 1.0         | 06/06/2024          | 23,100,000 | 17850.0        | KAB. KONAWE         |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 3     | 489434      | ALL NEW NMAX 155 | 1.0         | 06/06/2024          | 36,100,000 | 17850.0        | KAB. KOLAKA UTARA   |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 4     | 489434      | ALL NEW NMAX 155 | 1.0         | 06/06/2024          | 36,100,000 | 17850.0        | KAB. KOLAKA UTARA   |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 5     | 489434      | MIO M3 CW        | 1.0         | 06/06/2024          | 20,500,000 | 17850.0        | KAB. KONAWE         |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | ....  | ....        | ....             | ....        | ....                | ....       | ....           | ....                |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 30135 | 538849      | MIO M3 CW        | 5.0         | 20/06/2023          | 20,500,000 | 17422.0        | KAB. KONAWE SELATAN |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 30136 | 538849      | MIO M3 CW        | 5.0         | 21/06/2023          | 37,600,000 | 17422.0        | KOTA KENDARI        |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 30137 | 538849      | MIO M3 CW        | 5.0         | 22/06/2023          | 29,750,000 | 17422.0        | KAB. MUNA           |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 30138 | 538849      | MIO M3 CW        | 5.0         | 23/06/2023          | 37,600,000 | 17422.0        | KOTA KENDARI        |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+
# | 30139 | 538849      | FINO GRANDE 125  | 5.0         | 24/06/2023          | 29,750,000 | 17422.0        | KOTA KENDARI        |
# +-------+-------------+------------------+-------------+---------------------+------------+----------------+---------------------+

# %% [markdown]
# ## Sampling data
#
# Sampling data digunakan untuk memahami subset data tanpa harus memproses seluruh dataset disi.pada tahap ini samplng digunakan dengan mengelompokkan data berdasarkan kelasnya dengan warna yang berbeda pada data ini setiap model akan dikelompokkan dengan warna yang berbeda agar dapat mempermudah proses visualisasi data

# %% [markdown]
# ## Profiling data
#
# merupakan proses membuat ringkasan tentang setiap variable dalam dataset,termasuk tipe data dan meproses memeriksa, memahami, dan menganalisis struktur serta kualitas data sebelum digunakan dalam analisis lebih lanjut. pada data ini terdapat 8 kolom

# %% [markdown]
# ## Visualisasi Data
#
# Visualisasi data dalam analisis dataset digunakan ketika kita ingin memahami, mengeksplorasi, dan menyajikan pola dalam data. visualisasi membantu dalam mendeteksi pola, tren, hubungan antar fitur, serta distribusi data menampilkan visualisasi data dengan diagram membantu dalam mempercepat analisis data.

# %% [markdown]
# ## Korelasi dan Asosiasi
#
# merupakan proses menghitung koefisien korelasi untuk melihat hubungan linier antar variable yang bertujuan untuk menganalisis hubungan antar variabel dalam dataset.

# %%
# 1. Info umum dataset
print("=== Info Dataset ===")
print(df.info())

# 2. Statistik deskriptif
print("\n=== Statistik Deskriptif ===")
print(df.describe(include="all"))

# 3. Jumlah nilai unik per kolom
print("\n=== Nilai Unik per Kolom ===")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# 4. Cek missing values
print("\n=== Missing Values ===")
print(df.isnull().sum())

# 5. Korelasi numerik
print("\n=== Korelasi ===")
print(df.corr(numeric_only=True))
# Out:
# === Info Dataset ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30139 entries, 0 to 30138
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 30139 non-null  int64
#  1   No Faktur          30139 non-null  object
#  2   Model              30139 non-null  object
#  3   Kuantitas          30135 non-null  float64
#  4   Tanggal Pemesanan  30139 non-null  object
#  5   Harga              30139 non-null  float64
#  6   ID Pelanggan       30111 non-null  float64
#  7   Tempat Tinggal     30139 non-null  object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 1.8+ MB
# None
#
# === Statistik Deskriptif ===
#                   id No Faktur      Model     Kuantitas Tanggal Pemesanan  \
# count   30139.000000     30139      30139  30135.000000             30139
# unique           NaN      1406         69           NaN               264
# top              NaN    537434  MIO M3 CW           NaN        07/10/2023
# freq             NaN       675       7100           NaN              1895
# mean    15070.000000       NaN        NaN      6.457242               NaN
# std      8700.524218       NaN        NaN     10.937399               NaN
# min         1.000000       NaN        NaN   -290.000000               NaN
# 25%      7535.500000       NaN        NaN      1.000000               NaN
# 50%     15070.000000       NaN        NaN      3.000000               NaN
# 75%     22604.500000       NaN        NaN      8.000000               NaN
# max     30139.000000       NaN        NaN    240.000000               NaN
#
#                Harga  ID Pelanggan Tempat Tinggal
# count   3.013900e+04  30111.000000          30139
# unique           NaN           NaN             41
# top              NaN           NaN   KOTA KENDARI
# freq             NaN           NaN          10102
# mean    2.722931e+07  15432.399721            NaN
# std     6.632614e+06   1751.854112            NaN
# min     2.000000e+07  12347.000000            NaN
# 25%     2.195000e+07  14032.000000            NaN
# 50%     2.355000e+07  15382.000000            NaN
# 75%     3.265000e+07  17017.000000            NaN
# max     4.515000e+07  18281.000000            NaN
#
# === Nilai Unik per Kolom ===
# id: 30139 unique values
# No Faktur: 1406 unique values
# Model: 69 unique values
# Kuantitas: 65 unique values
# Tanggal Pemesanan: 264 unique values
# Harga: 48 unique values
# ID Pelanggan: 999 unique values
# Tempat Tinggal: 41 unique values
#
# === Missing Values ===
# id                    0
# No Faktur             0
# Model                 0
# Kuantitas             4
# Tanggal Pemesanan     0
# Harga                 0
# ID Pelanggan         28
# Tempat Tinggal        0
# dtype: int64
#
# === Korelasi ===
#                     id  Kuantitas     Harga  ID Pelanggan
# id            1.000000   0.049354  0.001608     -0.116462
# Kuantitas     0.049354   1.000000 -0.004670      0.017901
# Harga         0.001608  -0.004670  1.000000     -0.010736
# ID Pelanggan -0.116462   0.017901 -0.010736      1.000000

# %% [markdown]
# ## Ekplorasi Data
#
# Eksplorasi data adalah proses awal dalam analisis data untuk memahami karakteristik, distribusi, dan pola dalam dataset sehingga menghasilkan deskripsi statistik seperti mean, median, modus,standar deviasi,minimun, dan maskimum dengan menggunakan visualisasi data seperti grafik histogram scatter plot untuk melihat pola atau trend awal

# %% [markdown]
# ### Menapilkan data dalam bentuk diagram
#
# Menapilkan data dalam bentuk diagram
# Proses merupakan proses untuk menampilkan data menjadi diagram sekaligus menetukan median mean dan modus dari setiap label atau fiturnya dan membedakan warna diagram menyesuaikan dengan banyaknya class yang ada.

# %%
df.columns = df.columns.str.strip()  # hapus spasi depan & belakang
print(df.columns)
# Out:
# Index(['id', 'No Faktur', 'Model', 'Kuantitas', 'Tanggal Pemesanan', 'Harga',
#        'ID Pelanggan', 'Tempat Tinggal'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# Bersihkan kolom Harga
df["Harga"] = df["Harga"].replace({",": ""}, regex=True).astype(float)

# Parse tanggal
df["Tanggal Pemesanan"] = pd.to_datetime(
    df["Tanggal Pemesanan"],
    dayfirst=True,
    errors="coerce"
)

# ------------------- VISUALISASI -------------------

# 1. Jumlah Kuantitas per Model (Top 15)
plt.figure(figsize=(12,8))
data1 = df.groupby("Model")["Kuantitas"].sum().sort_values(ascending=False).head(15)
sns.barplot(y=data1.index, x=data1.values, palette="viridis", legend=False)
plt.title("Top 15 Jumlah Kuantitas per Model", fontsize=14, weight="bold")
plt.xlabel("Total Kuantitas")
plt.ylabel("Model")
plt.tight_layout()
plt.show()

# 2. Harga Rata-rata per Model (Top 15)
plt.figure(figsize=(12,8))
data2 = df.groupby("Model")["Harga"].mean().sort_values(ascending=False).head(15)
sns.barplot(y=data2.index, x=data2.values, palette="mako", legend=False)
plt.title("Top 15 Harga Rata-rata per Model", fontsize=14, weight="bold")
plt.xlabel("Harga (Rata-rata)")
plt.ylabel("Model")
plt.tight_layout()
plt.show()

# 3. Pesanan per Daerah (Top 15)
plt.figure(figsize=(12,8))
data3 = df.groupby("Tempat Tinggal")["id"].count().sort_values(ascending=False).head(15)
sns.barplot(y=data3.index, x=data3.values, palette="crest", legend=False)
plt.title("Top 15 Jumlah Pesanan per Daerah", fontsize=14, weight="bold")
plt.xlabel("Jumlah Pesanan")
plt.ylabel("Daerah")
plt.tight_layout()
plt.show()

# 4. Trend Penjualan per Hari
plt.figure(figsize=(14,6))
data4 = df.groupby("Tanggal Pemesanan")["Kuantitas"].sum().reset_index()
sns.lineplot(data=data4, x="Tanggal Pemesanan", y="Kuantitas", marker="o", color="steelblue")
plt.title("Trend Penjualan Harian", fontsize=14, weight="bold")
plt.xlabel("Tanggal Pemesanan")
plt.ylabel("Total Kuantitas")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4275136745.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=data1.index, x=data1.values, palette="viridis", legend=False)
# /tmp/ipython-input-4275136745.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=data2.index, x=data2.values, palette="mako", legend=False)
# /tmp/ipython-input-4275136745.py:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=data3.index, x=data3.values, palette="crest", legend=False)

# %% [markdown]
# ## Indentifikasi Masalah Data
#
# merupakan proses memahami kualitas data dan memastikan bahwa data yang akan kita analisis atau gunakan dalam model machine learning sudah bersih, lengkap, dan sesuai format yang diharapkan. Hal yang perlu diperhatikan adalah:
#
# Missing Values: Menemukan data yang hilang atau tidak lengkap.
#
# Outliers: Mendeteksi nilai-nilai ekstrem yang mungkin merupakan kesalahan atau anomali.
#
# Duplikasi Data: Mengidentifikasi baris atau entri yang duplikat.
#
# Inkonsistensi: Memeriksa apakah ada ketidaksesuaian dalam format atau nilai data.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# --- 1. Identifikasi Masalah Data ---
print("=== Missing Values ===")
print(df.isnull().sum())

print("\n=== Duplikasi ===")
print(f"Jumlah duplikat: {df.duplicated().sum()}")

print("\n=== Statistik Deskriptif ===")
print(df.describe())

# --- 2. Scatter Plot ---

plt.figure(figsize=(12,5))

# Scatter plot: Kuantitas vs Harga
plt.subplot(1,2,1)
plt.scatter(df["Kuantitas"], df["Harga"], alpha=0.5, c="blue")
plt.title("Scatter Plot Kuantitas vs Harga")
plt.xlabel("Kuantitas")
plt.ylabel("Harga")

# Scatter plot: ID Pelanggan vs Harga
plt.subplot(1,2,2)
plt.scatter(df["ID Pelanggan"], df["Harga"], alpha=0.5, c="green")
plt.title("Scatter Plot ID Pelanggan vs Harga")
plt.xlabel("ID Pelanggan")
plt.ylabel("Harga")

plt.tight_layout()
plt.show()
# Out:
# === Missing Values ===
# id                     0
# No Faktur              0
# Model                  0
# Kuantitas              4
# Tanggal Pemesanan    144
# Harga                  0
# ID Pelanggan          28
# Tempat Tinggal         0
# dtype: int64
#
# === Duplikasi ===
# Jumlah duplikat: 0
#
# === Statistik Deskriptif ===
#                  id     Kuantitas              Tanggal Pemesanan  \
# count  30139.000000  30135.000000                          29995
# mean   15070.000000      6.457242  2023-11-30 17:02:08.301383680
# min        1.000000   -290.000000            2023-06-08 00:00:00
# 25%     7535.500000      1.000000            2023-09-01 00:00:00
# 50%    15070.000000      3.000000            2023-11-18 00:00:00
# 75%    22604.500000      8.000000            2024-03-02 00:00:00
# max    30139.000000    240.000000            2024-06-06 00:00:00
# std     8700.524218     10.937399                            NaN
#
#               Harga  ID Pelanggan
# count  3.013900e+04  30111.000000
# mean   2.722931e+07  15432.399721
# min    2.000000e+07  12347.000000
# 25%    2.195000e+07  14032.000000
# 50%    2.355000e+07  15382.000000
# 75%    3.265000e+07  17017.000000
# max    4.515000e+07  18281.000000
# std    6.632614e+06   1751.854112

# %% [markdown]
# ## Validasi data
#
# Validasi data dilakukan untuk memastikan bahwa data yang digunakan bersih, lengkap, dan sesuai sebelum dianalisis atau divisualisasikan dan memastikan apakah data memcerminkan realitas atau fenomena yang ingin dipelajari
